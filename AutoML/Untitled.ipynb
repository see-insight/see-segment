# %%
import sklearn.datasets
import sklearn.metrics

import autosklearn.classification

# %%
import string

# %%
df = pd.read_csv (r'best_run.csv',header=None,names=["fitness", "algorithm", "activation", 
                                                     "alpha","C","gamma","kernel","learning_rate",
                                                    "max_depth","max_iter","n_extimators","n_neighbors",
                                                     "solver","smooth"])

# %%
df['fitness'] = df['fitness'].str[7:]
df['algorithm'] = df['algorithm'].str[4:-1]
df['activation'] = df['activation'].str[2:-1]
df['kernel'] = df['kernel'].str[2:-1]
df['solver'] = df['solver'].str[2:-1]
df['smooth'] = df['smooth'].str[:-2]

# %%
df.sort_values(by='fitness')
# Out:
#                  fitness         algorithm activation    alpha       C  \
# 0   0.025000000000000022     Decision Tree   logistic  0.00001      10
# 3   0.025000000000000022     Decision Tree   identity  0.00001    1000
# 4   0.025000000000000022     Decision Tree   identity  0.00001    1000
# 5   0.025000000000000022     Decision Tree   identity  0.10000  100000
# 6   0.025000000000000022     Decision Tree   identity  0.10000    1000
# 7   0.025000000000000022     Decision Tree   identity  0.00001    1000
# 8   0.025000000000000022     Decision Tree       relu  0.00001  100000
# 9   0.025000000000000022     Decision Tree   identity  0.10000    1000
# 10  0.025000000000000022     Decision Tree   identity  0.10000    1000
# 1   0.050000000000000044     Random Forest   identity  0.00100      10
# 2   0.050000000000000044     Decision Tree   identity  0.00001    1000
# 11  0.050000000000000044  Gaussian Process   logistic  0.01000   10000
#
# ...

# %%
df = df.head(1)

# %%
df
# Out:
#                 fitness      algorithm activation    alpha   C  gamma kernel  \
# 0  0.025000000000000022  Decision Tree   logistic  0.00001  10   0.01    rbf
#
#    learning_rate  max_depth  max_iter  n_extimators  n_neighbors solver  \
# 0            1.0         10       400           850           13    sgd
#
#              smooth
# 0   100000000000000

# %%
if(df.iloc[0,1] == 'Decision Tree'):
    print('yes')
elif(df.iloc[0,1] == 'Decision Tree'):
# Out:
# yes
