# %% [markdown]
# # Genetic Search Plotting
# The purpose of this notebook is to experiment with and benchmark Genetic Search.
# In this notebook, we will also experiment with scripts that will be later run on the HPCC.

# %% [markdown]
# ## Generational Fitness
# This section will experiment with the toy data sets.
# Here will create plots that demonstrate how the best fitness score changes over with each
# generation. We expect the fitness score to monotonically decrease.

# %% [markdown]
# ## Setup: Generate trial data
# It would be better to run this python script on the terminal
# multiple times in parallel sessions in order to generate multiple trials
# quickly. To do this run the following commands in separate terminal tabs
# simultaneously (make sure to change `--filename-trail` for each distinct execution):
# ```shell
# conda activate ./envs
# python dataset_script.py --filename-tail=trial_1 --num-gen=30 --pop-size=30
# ```
# **Warning**: You might experience strange errors if you run the plotting cell before
# all the trial data is fully generated.

# %%
# Create datasets
# %run dataset_script.py --filename-tail=trial_1 --num-gen=30 --pop-size=30
# Out:
# Running Moons Dataset
# Initializing a new random population
# Generation 0/30 of population size 30
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 60
# 	alpha = 0.338
# 	max_depth = 5
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f475ddc0>
# Time: 0.042 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 78
# 	alpha = 0.962
# 	max_depth = 9
# 	n_estimators = 7
# 	n_neighbors = 8
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f475d610>
# Time: 0.013 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 31
# 	alpha = 0.192
# 	max_depth = 2
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f475d1f0>
# Time: 0.046 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 79
# 	alpha = 0.077
# 	max_depth = 3
# 	n_estimators = 3
# 	n_neighbors = 2
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f475d4c0>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 56
# 	alpha = 0.411
# 	max_depth = 5
# 	n_estimators = 8
# 	n_neighbors = 1
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f4aa9f70>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 69
# 	alpha = 0.873
# 	max_depth = 3
# 	n_estimators = 4
# 	n_neighbors = 6
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4aa9100>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 77
# 	alpha = 0.635
# 	max_depth = 3
# 	n_estimators = 8
# 	n_neighbors = 7
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f4aa9d60>
# Time: 0.014 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 23
# 	alpha = 0.818
# 	max_depth = 9
# 	n_estimators = 5
# 	n_neighbors = 4
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f4aa99a0>
# Time: 0.18 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 76
# 	alpha = 0.165
# 	max_depth = 5
# 	n_estimators = 8
# 	n_neighbors = 9
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f4aa9430>
# Time: 0.015 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 49
# 	alpha = 0.809
# 	max_depth = 4
# 	n_estimators = 3
# 	n_neighbors = 7
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f4aa9370>
# Time: 0.003 s
# fitness=0.3333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 84
# 	alpha = 0.019
# 	max_depth = 7
# 	n_estimators = 2
# 	n_neighbors = 4
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f4aa93d0>
# Time: 0.005 s
# fitness=0.2916666666666667
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 92
# 	alpha = 0.377
# 	max_depth = 3
# 	n_estimators = 3
# 	n_neighbors = 7
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f4aa9850>
# Time: 0.045 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 16
# 	alpha = 0.852
# 	max_depth = 1
# 	n_estimators = 3
# 	n_neighbors = 3
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f4aa9640>
# Time: 0.002 s
# fitness=0.2916666666666667
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 94
# 	alpha = 0.712
# 	max_depth = 1
# 	n_estimators = 9
# 	n_neighbors = 2
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4aa9670>
# Time: 0.21 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 59
# 	alpha = 0.193
# 	max_depth = 8
# 	n_estimators = 3
# 	n_neighbors = 4
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f4aa9d90>
# Time: 0.008 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 48
# 	alpha = 0.307
# 	max_depth = 1
# 	n_estimators = 9
# 	n_neighbors = 4
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f4aa91c0>
# Time: 0.044 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 4
# 	alpha = 0.351
# 	max_depth = 2
# 	n_estimators = 6
# 	n_neighbors = 9
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4582640>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 53
# 	alpha = 0.258
# 	max_depth = 8
# 	n_estimators = 1
# 	n_neighbors = 7
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f47cea90>
# Time: 0.002 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 17
# 	alpha = 0.939
# 	max_depth = 6
# 	n_estimators = 9
# 	n_neighbors = 7
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f47ce9d0>
# Time: 0.129 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 24
# 	alpha = 0.763
# 	max_depth = 1
# 	n_estimators = 7
# 	n_neighbors = 6
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f47ce0d0>
# Time: 0.015 s
# fitness=0.4583333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 82
# 	alpha = 0.842
# 	max_depth = 6
# 	n_estimators = 9
# 	n_neighbors = 1
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f45828e0>
# RUNNING EVAL FOR GNB
# Time: 0.001 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 40
# 	alpha = 0.47
# 	max_depth = 9
# 	n_estimators = 9
# 	n_neighbors = 7
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f4582280>
# Time: 0.004 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 39
# 	alpha = 0.784
# 	max_depth = 9
# 	n_estimators = 1
# 	n_neighbors = 7
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4582b50>
# Time: 0.003 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 61
# 	alpha = 0.014
# 	max_depth = 8
# 	n_estimators = 5
# 	n_neighbors = 1
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4582a60>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 48
# 	alpha = 0.158
# 	max_depth = 6
# 	n_estimators = 2
# 	n_neighbors = 4
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f4582e50>
# RUNNING EVAL FOR GNB
# Time: 0.003 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 73
# 	alpha = 0.847
# 	max_depth = 9
# 	n_estimators = 1
# 	n_neighbors = 5
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4582490>
# RUNNING EVAL FOR KNN
# Time: 0.006 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 31
# 	alpha = 0.107
# 	max_depth = 7
# 	n_estimators = 1
# 	n_neighbors = 6
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4582ee0>
# Time: 0.047 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 64
# 	alpha = 0.103
# 	max_depth = 1
# 	n_estimators = 6
# 	n_neighbors = 2
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f4582730>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 36
# 	alpha = 0.292
# 	max_depth = 1
# 	n_estimators = 4
# 	n_neighbors = 6
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4582160>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 74
# 	alpha = 0.743
# 	max_depth = 9
# 	n_estimators = 6
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4582820>
# RUNNING EVAL FOR GNB
# Time: 0.003 s
# fitness=0.08333333333333333
#
# #BEST [0.041666666666666664,  ['Gaussian Process', 31, 0.107, 7, 1, 6, 0.2]]
# Mutating Population
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# Generation 1/30 of population size 30
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 70
# 	alpha = 0.268
# 	max_depth = 5
# 	n_estimators = 1
# 	n_neighbors = 3
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f4aa9040>
# Time: 0.005 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 56
# 	alpha = 0.354
# 	max_depth = 7
# 	n_estimators = 5
# 	n_neighbors = 2
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f4aa9430>
# Time: 0.049 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 12
# 	alpha = 0.455
# 	max_depth = 5
# 	n_estimators = 6
# 	n_neighbors = 5
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f4aa9d60>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 76
# 	alpha = 0.405
# 	max_depth = 5
# 	n_estimators = 7
# 	n_neighbors = 7
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4aa9f70>
# Time: 0.012 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 75
# 	alpha = 0.99
# 	max_depth = 2
# 	n_estimators = 1
# 	n_neighbors = 5
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f475d640>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 76
# 	alpha = 0.925
# 	max_depth = 6
# 	n_estimators = 9
# 	n_neighbors = 2
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f475d580>
# Time: 0.146 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 2
# 	alpha = 0.395
# 	max_depth = 3
# 	n_estimators = 3
# 	n_neighbors = 9
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f475d340>
# Time: 0.012 s
# fitness=0.5416666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 45
# 	alpha = 0.535
# 	max_depth = 1
# 	n_estimators = 6
# 	n_neighbors = 2
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f475d760>
# Time: 0.158 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 80
# 	alpha = 0.983
# 	max_depth = 7
# 	n_estimators = 9
# 	n_neighbors = 1
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f475d220>
# /home/davin/Documents/GitHub/see-segment/see-clasify/envs/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:402: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# /home/davin/Documents/GitHub/see-segment/see-clasify/envs/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:411: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# Time: 0.174 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 59
# 	alpha = 0.48
# 	max_depth = 5
# 	n_estimators = 5
# 	n_neighbors = 7
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f475d1c0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 94
# 	alpha = 0.891
# 	max_depth = 7
# 	n_estimators = 4
# 	n_neighbors = 1
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f475d6d0>
# Time: 0.157 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 22
# 	alpha = 0.751
# 	max_depth = 6
# 	n_estimators = 9
# 	n_neighbors = 5
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f475d7c0>
# Time: 0.002 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 99
# 	alpha = 0.359
# 	max_depth = 3
# 	n_estimators = 1
# 	n_neighbors = 8
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f475d160>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 77
# 	alpha = 0.104
# 	max_depth = 7
# 	n_estimators = 5
# 	n_neighbors = 2
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f475de50>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 15
# 	alpha = 0.313
# 	max_depth = 6
# 	n_estimators = 8
# 	n_neighbors = 1
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f475db20>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 73
# 	alpha = 0.725
# 	max_depth = 7
# 	n_estimators = 9
# 	n_neighbors = 6
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f475dc70>
# Time: 0.001 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 68
# 	alpha = 0.186
# 	max_depth = 9
# 	n_estimators = 1
# 	n_neighbors = 7
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f51dc460>
# Time: 0.004 s
# fitness=0.25
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 31
# 	alpha = 0.107
# 	max_depth = 7
# 	n_estimators = 1
# 	n_neighbors = 6
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f51dc880>
# Time: 0.046 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 73
# 	alpha = 0.847
# 	max_depth = 9
# 	n_estimators = 1
# 	n_neighbors = 5
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f51dc730>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 4
# 	alpha = 0.351
# 	max_depth = 2
# 	n_estimators = 6
# 	n_neighbors = 9
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f51dcc40>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 31
# 	alpha = 0.107
# 	max_depth = 7
# 	n_estimators = 1
# 	n_neighbors = 6
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4582610>
# Time: 0.036 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 73
# 	alpha = 0.847
# 	max_depth = 9
# 	n_estimators = 1
# 	n_neighbors = 5
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f45826a0>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 4
# 	alpha = 0.351
# 	max_depth = 2
# 	n_estimators = 6
# 	n_neighbors = 9
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4582af0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 48
# 	alpha = 0.307
# 	max_depth = 1
# 	n_estimators = 9
# 	n_neighbors = 4
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f4582be0>
# Time: 0.045 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 92
# 	alpha = 0.192
# 	max_depth = 3
# 	n_estimators = 3
# 	n_neighbors = 3
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f4a4ed30>
# Time: 0.045 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 31
# 	alpha = 0.377
# 	max_depth = 2
# 	n_estimators = 2
# 	n_neighbors = 7
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f4a4e7c0>
# Time: 0.085 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 60
# 	alpha = 0.338
# 	max_depth = 5
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f6db93a0>
# Time: 0.076 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 36
# 	alpha = 0.292
# 	max_depth = 1
# 	n_estimators = 4
# 	n_neighbors = 6
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4ae90a0>
# RUNNING EVAL FOR GNB
# Time: 0.003 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 82
# 	alpha = 0.842
# 	max_depth = 6
# 	n_estimators = 9
# 	n_neighbors = 4
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f4ae9760>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 48
# 	alpha = 0.158
# 	max_depth = 6
# 	n_estimators = 2
# 	n_neighbors = 1
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f4ae9d60>
# RUNNING EVAL FOR GNB
# Time: 0.003 s
# fitness=0.08333333333333333
#
# #BEST [0.041666666666666664,  ['K Nearest Neighbors', 59, 0.48, 5, 5, 7, 0.1]]
# Mutating Population
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# Generation 2/30 of population size 30
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 75
# 	alpha = 0.195
# 	max_depth = 6
# 	n_estimators = 8
# 	n_neighbors = 4
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f4aa9ee0>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 51
# 	alpha = 0.639
# 	max_depth = 2
# 	n_estimators = 6
# 	n_neighbors = 5
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4aa9bb0>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 11
# 	alpha = 0.515
# 	max_depth = 8
# 	n_estimators = 9
# 	n_neighbors = 3
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f6da8490>
# Time: 0.001 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 83
# 	alpha = 0.388
# 	max_depth = 5
# 	n_estimators = 8
# 	n_neighbors = 4
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f47cea90>
# Time: 0.014 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 11
# 	alpha = 0.53
# 	max_depth = 8
# 	n_estimators = 8
# 	n_neighbors = 4
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f6db9460>
# RUNNING EVAL FOR GNB
# Time: 0.003 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 98
# 	alpha = 0.183
# 	max_depth = 3
# 	n_estimators = 6
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4932be0>
# Time: 0.011 s
# fitness=0.5416666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 85
# 	alpha = 0.027
# 	max_depth = 5
# 	n_estimators = 9
# 	n_neighbors = 1
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4582dc0>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 93
# 	alpha = 0.492
# 	max_depth = 1
# 	n_estimators = 9
# 	n_neighbors = 7
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f4582880>
# /home/davin/Documents/GitHub/see-segment/see-clasify/envs/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:402: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# /home/davin/Documents/GitHub/see-segment/see-clasify/envs/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:411: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# Time: 0.138 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 62
# 	alpha = 0.867
# 	max_depth = 8
# 	n_estimators = 5
# 	n_neighbors = 6
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4ae9760>
# Time: 0.145 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 26
# 	alpha = 0.367
# 	max_depth = 4
# 	n_estimators = 2
# 	n_neighbors = 4
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f51dcc40>
# Time: 0.045 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 33
# 	alpha = 0.652
# 	max_depth = 1
# 	n_estimators = 7
# 	n_neighbors = 3
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f51dc190>
# Time: 0.002 s
# fitness=0.2916666666666667
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 98
# 	alpha = 0.687
# 	max_depth = 7
# 	n_estimators = 7
# 	n_neighbors = 3
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f51dccd0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 88
# 	alpha = 0.553
# 	max_depth = 2
# 	n_estimators = 8
# 	n_neighbors = 6
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f51dcdf0>
# Time: 0.001 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 60
# 	alpha = 0.731
# 	max_depth = 3
# 	n_estimators = 5
# 	n_neighbors = 1
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f51dc3d0>
# Time: 0.001 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 60
# 	alpha = 0.823
# 	max_depth = 7
# 	n_estimators = 2
# 	n_neighbors = 6
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f51dc430>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 78
# 	alpha = 0.207
# 	max_depth = 7
# 	n_estimators = 5
# 	n_neighbors = 8
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f4cfa820>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 76
# 	alpha = 0.136
# 	max_depth = 5
# 	n_estimators = 1
# 	n_neighbors = 3
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4cfae80>
# RUNNING EVAL FOR KNN
# Time: 0.008 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 59
# 	alpha = 0.48
# 	max_depth = 5
# 	n_estimators = 5
# 	n_neighbors = 7
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4cfac40>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 12
# 	alpha = 0.455
# 	max_depth = 5
# 	n_estimators = 6
# 	n_neighbors = 5
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f4cfa9a0>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 56
# 	alpha = 0.354
# 	max_depth = 7
# 	n_estimators = 5
# 	n_neighbors = 2
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f4cfa640>
# Time: 0.039 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 59
# 	alpha = 0.455
# 	max_depth = 5
# 	n_estimators = 6
# 	n_neighbors = 7
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4cfa7c0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 12
# 	alpha = 0.48
# 	max_depth = 5
# 	n_estimators = 5
# 	n_neighbors = 5
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f4a4e760>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 56
# 	alpha = 0.354
# 	max_depth = 7
# 	n_estimators = 1
# 	n_neighbors = 6
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f8911bb0>
# Time: 0.035 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 31
# 	alpha = 0.107
# 	max_depth = 7
# 	n_estimators = 5
# 	n_neighbors = 2
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f8911040>
# Time: 0.037 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 4
# 	alpha = 0.847
# 	max_depth = 2
# 	n_estimators = 6
# 	n_neighbors = 9
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f89110a0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 73
# 	alpha = 0.351
# 	max_depth = 9
# 	n_estimators = 1
# 	n_neighbors = 5
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f8911ca0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 92
# 	alpha = 0.307
# 	max_depth = 1
# 	n_estimators = 9
# 	n_neighbors = 7
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f8911b20>
# Time: 0.043 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 48
# 	alpha = 0.377
# 	max_depth = 3
# 	n_estimators = 3
# 	n_neighbors = 4
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f89117f0>
# Time: 0.061 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 60
# 	alpha = 0.338
# 	max_depth = 5
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f41af550>
# Time: 0.043 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 31
# 	alpha = 0.192
# 	max_depth = 2
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f41afdf0>
# Time: 0.049 s
# fitness=0.041666666666666664
#
# #BEST [0.0,  ['K Nearest Neighbors', 76, 0.136, 5, 1, 3, 0.1]]
# Mutating Population
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# Generation 3/30 of population size 30
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 63
# 	alpha = 0.006
# 	max_depth = 2
# 	n_estimators = 8
# 	n_neighbors = 2
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f4aa9430>
# Time: 0.156 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 99
# 	alpha = 0.44
# 	max_depth = 7
# 	n_estimators = 6
# 	n_neighbors = 1
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4aa9d60>
# Time: 0.015 s
# fitness=0.25
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 68
# 	alpha = 0.697
# 	max_depth = 3
# 	n_estimators = 6
# 	n_neighbors = 5
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f45826a0>
# RUNNING EVAL FOR KNN
# Time: 0.006 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 13
# 	alpha = 0.648
# 	max_depth = 2
# 	n_estimators = 7
# 	n_neighbors = 5
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4582be0>
# Time: 0.002 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 18
# 	alpha = 0.956
# 	max_depth = 4
# 	n_estimators = 8
# 	n_neighbors = 5
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f5bb4af0>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 80
# 	alpha = 0.673
# 	max_depth = 9
# 	n_estimators = 3
# 	n_neighbors = 3
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f5bb4ca0>
# Time: 0.007 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 94
# 	alpha = 0.333
# 	max_depth = 6
# 	n_estimators = 7
# 	n_neighbors = 7
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f4ae97c0>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 20
# 	alpha = 0.834
# 	max_depth = 5
# 	n_estimators = 4
# 	n_neighbors = 8
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f475d580>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 97
# 	alpha = 0.439
# 	max_depth = 1
# 	n_estimators = 9
# 	n_neighbors = 8
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f475d850>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 76
# 	alpha = 0.667
# 	max_depth = 6
# 	n_estimators = 5
# 	n_neighbors = 5
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f475df70>
# Time: 0.14 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 96
# 	alpha = 0.13
# 	max_depth = 2
# 	n_estimators = 5
# 	n_neighbors = 6
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f475de50>
# Time: 0.168 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 65
# 	alpha = 0.971
# 	max_depth = 7
# 	n_estimators = 4
# 	n_neighbors = 2
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f41af9d0>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 31
# 	alpha = 0.296
# 	max_depth = 4
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f90456d0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 21
# 	alpha = 0.67
# 	max_depth = 1
# 	n_estimators = 1
# 	n_neighbors = 8
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f8911dc0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 100
# 	alpha = 0.663
# 	max_depth = 9
# 	n_estimators = 3
# 	n_neighbors = 1
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f8911130>
# Time: 0.153 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 55
# 	alpha = 0.261
# 	max_depth = 6
# 	n_estimators = 6
# 	n_neighbors = 7
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f8911c40>
# Time: 0.002 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 25
# 	alpha = 0.561
# 	max_depth = 5
# 	n_estimators = 9
# 	n_neighbors = 8
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f8911850>
# RUNNING EVAL FOR GNB
# Time: 0.003 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 76
# 	alpha = 0.136
# 	max_depth = 5
# 	n_estimators = 1
# 	n_neighbors = 3
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f51dc370>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 98
# 	alpha = 0.687
# 	max_depth = 7
# 	n_estimators = 7
# 	n_neighbors = 3
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f51dc4f0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 59
# 	alpha = 0.48
# 	max_depth = 5
# 	n_estimators = 5
# 	n_neighbors = 7
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f51dc400>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 76
# 	alpha = 0.136
# 	max_depth = 5
# 	n_estimators = 1
# 	n_neighbors = 3
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f51dc310>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 98
# 	alpha = 0.687
# 	max_depth = 7
# 	n_estimators = 7
# 	n_neighbors = 3
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f6db9460>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 59
# 	alpha = 0.48
# 	max_depth = 5
# 	n_estimators = 6
# 	n_neighbors = 5
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f455b460>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 12
# 	alpha = 0.455
# 	max_depth = 5
# 	n_estimators = 5
# 	n_neighbors = 7
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f455b310>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 56
# 	alpha = 0.354
# 	max_depth = 7
# 	n_estimators = 5
# 	n_neighbors = 2
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f455b4f0>
# Time: 0.042 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 31
# 	alpha = 0.107
# 	max_depth = 7
# 	n_estimators = 1
# 	n_neighbors = 6
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f455ba90>
# Time: 0.043 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 73
# 	alpha = 0.351
# 	max_depth = 2
# 	n_estimators = 1
# 	n_neighbors = 9
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f455b670>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 4
# 	alpha = 0.847
# 	max_depth = 9
# 	n_estimators = 6
# 	n_neighbors = 5
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f455b040>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 92
# 	alpha = 0.307
# 	max_depth = 1
# 	n_estimators = 9
# 	n_neighbors = 4
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f455bbe0>
# Time: 0.043 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 48
# 	alpha = 0.377
# 	max_depth = 3
# 	n_estimators = 3
# 	n_neighbors = 7
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f455bd30>
# Time: 0.043 s
# fitness=0.041666666666666664
#
# #BEST [0.0,  ['K Nearest Neighbors', 31, 0.296, 4, 2, 3, 0.2]]
# Mutating Population
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# Generation 4/30 of population size 30
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 94
# 	alpha = 0.397
# 	max_depth = 5
# 	n_estimators = 7
# 	n_neighbors = 6
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f41af8b0>
# Time: 0.041 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 100
# 	alpha = 0.856
# 	max_depth = 3
# 	n_estimators = 9
# 	n_neighbors = 4
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f455bb80>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 55
# 	alpha = 0.271
# 	max_depth = 6
# 	n_estimators = 5
# 	n_neighbors = 1
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f455b760>
# Time: 0.151 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 44
# 	alpha = 0.793
# 	max_depth = 1
# 	n_estimators = 1
# 	n_neighbors = 4
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f51dc370>
# Time: 0.002 s
# fitness=0.2916666666666667
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 5
# 	alpha = 0.853
# 	max_depth = 9
# 	n_estimators = 6
# 	n_neighbors = 9
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f51dcc70>
# Time: 0.002 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 71
# 	alpha = 0.061
# 	max_depth = 8
# 	n_estimators = 5
# 	n_neighbors = 7
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f475d4f0>
# Time: 0.125 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 45
# 	alpha = 0.8
# 	max_depth = 2
# 	n_estimators = 8
# 	n_neighbors = 1
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f475d850>
# Time: 0.172 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 3
# 	alpha = 0.068
# 	max_depth = 1
# 	n_estimators = 7
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f41af340>
# Time: 0.002 s
# fitness=0.2916666666666667
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 46
# 	alpha = 0.333
# 	max_depth = 5
# 	n_estimators = 5
# 	n_neighbors = 4
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f5bb4280>
# Time: 0.001 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 46
# 	alpha = 0.607
# 	max_depth = 4
# 	n_estimators = 4
# 	n_neighbors = 1
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f6db9760>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 38
# 	alpha = 0.638
# 	max_depth = 1
# 	n_estimators = 7
# 	n_neighbors = 9
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f4a32700>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 88
# 	alpha = 0.514
# 	max_depth = 9
# 	n_estimators = 1
# 	n_neighbors = 2
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f4a328e0>
# Time: 0.05 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 1
# 	alpha = 0.099
# 	max_depth = 2
# 	n_estimators = 9
# 	n_neighbors = 5
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4a32520>
# Time: 0.002 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 96
# 	alpha = 0.334
# 	max_depth = 8
# 	n_estimators = 8
# 	n_neighbors = 5
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4a32250>
# Time: 0.002 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 9
# 	alpha = 0.335
# 	max_depth = 6
# 	n_estimators = 7
# 	n_neighbors = 2
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4a32f70>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 33
# 	alpha = 0.13
# 	max_depth = 2
# 	n_estimators = 7
# 	n_neighbors = 1
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f8911850>
# RUNNING EVAL FOR GNB
# Time: 0.003 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 31
# 	alpha = 0.165
# 	max_depth = 9
# 	n_estimators = 7
# 	n_neighbors = 5
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4aa9ee0>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 31
# 	alpha = 0.296
# 	max_depth = 4
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4aa9d60>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 76
# 	alpha = 0.136
# 	max_depth = 5
# 	n_estimators = 1
# 	n_neighbors = 3
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4932790>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 98
# 	alpha = 0.687
# 	max_depth = 7
# 	n_estimators = 7
# 	n_neighbors = 3
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f8ed7430>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 31
# 	alpha = 0.136
# 	max_depth = 5
# 	n_estimators = 1
# 	n_neighbors = 3
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f8ed75b0>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 76
# 	alpha = 0.296
# 	max_depth = 4
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f457d970>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 98
# 	alpha = 0.687
# 	max_depth = 7
# 	n_estimators = 7
# 	n_neighbors = 3
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f4cfa820>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.0
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 59
# 	alpha = 0.48
# 	max_depth = 5
# 	n_estimators = 5
# 	n_neighbors = 7
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4cfae80>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 12
# 	alpha = 0.455
# 	max_depth = 5
# 	n_estimators = 6
# 	n_neighbors = 5
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f4cfa9a0>
# Time: 0.047 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 56
# 	alpha = 0.354
# 	max_depth = 7
# 	n_estimators = 5
# 	n_neighbors = 2
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f4cfa3d0>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 31
# 	alpha = 0.847
# 	max_depth = 7
# 	n_estimators = 1
# 	n_neighbors = 5
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4cfac10>
# Time: 0.035 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 73
# 	alpha = 0.107
# 	max_depth = 9
# 	n_estimators = 1
# 	n_neighbors = 6
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4ae90a0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 4
# 	alpha = 0.307
# 	max_depth = 1
# 	n_estimators = 9
# 	n_neighbors = 4
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f5077130>
# Time: 0.05 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 48
# 	alpha = 0.351
# 	max_depth = 2
# 	n_estimators = 6
# 	n_neighbors = 9
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f50779a0>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.041666666666666664
#
# #BEST [0.0,  ['K Nearest Neighbors', 76, 0.296, 4, 2, 3, 0.2]]
# Mutating Population
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# Generation 5/30 of population size 30
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 52
# 	alpha = 0.478
# 	max_depth = 1
# 	n_estimators = 2
# 	n_neighbors = 7
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f455bd30>
# Time: 0.002 s
# fitness=0.2916666666666667
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 53
# 	alpha = 0.932
# 	max_depth = 8
# 	n_estimators = 3
# 	n_neighbors = 6
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f455b220>
# Time: 0.155 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 43
# 	alpha = 0.056
# 	max_depth = 3
# 	n_estimators = 4
# 	n_neighbors = 3
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f455b310>
# Time: 0.001 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 26
# 	alpha = 0.219
# 	max_depth = 9
# 	n_estimators = 1
# 	n_neighbors = 9
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f455ba90>
# Time: 0.004 s
# fitness=0.2916666666666667
#
# <class 'see.Workflow.workflow'> parameters:
# ...
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 78
# 	alpha = 0.167
# 	max_depth = 5
# 	n_estimators = 8
# 	n_neighbors = 8
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f46d68b0>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 32
# 	alpha = 0.787
# 	max_depth = 7
# 	n_estimators = 4
# 	n_neighbors = 9
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f457d5e0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 38
# 	alpha = 0.9
# 	max_depth = 7
# 	n_estimators = 9
# 	n_neighbors = 9
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f438dd00>
# Time: 0.017 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 33
# 	alpha = 0.18
# 	max_depth = 4
# 	n_estimators = 8
# 	n_neighbors = 2
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f8e8b5b0>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 30
# 	alpha = 0.558
# 	max_depth = 7
# 	n_estimators = 9
# 	n_neighbors = 3
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f438d580>
# Time: 0.2 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 19
# 	alpha = 0.997
# 	max_depth = 1
# 	n_estimators = 2
# 	n_neighbors = 6
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f457d130>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 94
# 	alpha = 0.248
# 	max_depth = 2
# 	n_estimators = 1
# 	n_neighbors = 8
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f47ceb80>
# Time: 0.223 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 86
# 	alpha = 0.724
# 	max_depth = 7
# 	n_estimators = 6
# 	n_neighbors = 3
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f44d37f0>
# Time: 0.059 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 18
# 	alpha = 0.286
# 	max_depth = 3
# 	n_estimators = 7
# 	n_neighbors = 6
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f44d3d00>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 19
# 	alpha = 0.016
# 	max_depth = 5
# 	n_estimators = 3
# 	n_neighbors = 7
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f44d3130>
# Time: 0.002 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 57
# 	alpha = 0.391
# 	max_depth = 2
# 	n_estimators = 4
# 	n_neighbors = 9
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f44d35b0>
# Time: 0.013 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 66
# 	alpha = 0.574
# 	max_depth = 5
# 	n_estimators = 7
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f44d3e50>
# Time: 0.057 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 59
# 	alpha = 0.621
# 	max_depth = 4
# 	n_estimators = 2
# 	n_neighbors = 7
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f44d3520>
# Time: 0.005 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 86
# 	alpha = 0.126
# 	max_depth = 1
# 	n_estimators = 2
# 	n_neighbors = 2
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f44d3160>
# Time: 0.051 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 66
# 	alpha = 0.574
# 	max_depth = 5
# 	n_estimators = 7
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f44d3a30>
# Time: 0.059 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 59
# 	alpha = 0.621
# 	max_depth = 4
# 	n_estimators = 2
# 	n_neighbors = 7
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f47ce700>
# Time: 0.006 s
# fitness=0.20833333333333334
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 86
# 	alpha = 0.933
# 	max_depth = 1
# 	n_estimators = 2
# 	n_neighbors = 6
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f47493d0>
# Time: 0.042 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 5
# 	alpha = 0.126
# 	max_depth = 9
# 	n_estimators = 4
# 	n_neighbors = 2
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f4749430>
# Time: 0.046 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 41
# 	alpha = 0.157
# 	max_depth = 9
# 	n_estimators = 4
# 	n_neighbors = 1
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4749bb0>
# Time: 0.059 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 10
# 	alpha = 0.773
# 	max_depth = 2
# 	n_estimators = 2
# 	n_neighbors = 4
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f4749250>
# Time: 0.05 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 17
# 	alpha = 0.739
# 	max_depth = 9
# 	n_estimators = 3
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f47496d0>
# Time: 0.055 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 39
# 	alpha = 0.174
# 	max_depth = 7
# 	n_estimators = 7
# 	n_neighbors = 5
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4749670>
# Time: 0.053 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 54
# 	alpha = 0.78
# 	max_depth = 8
# 	n_estimators = 1
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4749fd0>
# Time: 0.058 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 73
# 	alpha = 0.196
# 	max_depth = 6
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f4749eb0>
# Time: 0.054 s
# fitness=0.041666666666666664
#
# #BEST [0.041666666666666664,  ['Gaussian Process', 66, 0.574, 5, 7, 8, 0.1]]
# Mutating Population
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# Generation 30/30 of population size 30
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 2
# 	alpha = 0.305
# 	max_depth = 4
# 	n_estimators = 8
# 	n_neighbors = 5
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f44d3a30>
# Time: 0.017 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 57
# 	alpha = 0.7
# 	max_depth = 4
# 	n_estimators = 4
# 	n_neighbors = 4
# 	length_scale = 0.7
#
# <see.base_classes.pipedata object at 0x7f06f44d3520>
# Time: 0.002 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 78
# 	alpha = 0.952
# 	max_depth = 1
# 	n_estimators = 8
# 	n_neighbors = 2
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f44d35b0>
# Time: 0.014 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 37
# 	alpha = 0.978
# 	max_depth = 6
# 	n_estimators = 1
# 	n_neighbors = 3
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f44d3d30>
# RUNNING EVAL FOR KNN
# Time: 0.004 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 98
# 	alpha = 0.568
# 	max_depth = 2
# 	n_estimators = 5
# 	n_neighbors = 2
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f44d3af0>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Decision Tree
# 	max_iter = 97
# 	alpha = 0.983
# 	max_depth = 3
# 	n_estimators = 9
# 	n_neighbors = 5
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f44d3430>
# Time: 0.003 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 82
# 	alpha = 0.566
# 	max_depth = 9
# 	n_estimators = 8
# 	n_neighbors = 2
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f6d2b0a0>
# Time: 0.232 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 43
# 	alpha = 0.84
# 	max_depth = 1
# 	n_estimators = 1
# 	n_neighbors = 9
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f4932130>
# RUNNING EVAL FOR KNN
# Time: 0.003 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 75
# 	alpha = 0.103
# 	max_depth = 6
# 	n_estimators = 7
# 	n_neighbors = 2
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f44d3160>
# Time: 0.015 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 8
# 	alpha = 0.445
# 	max_depth = 8
# 	n_estimators = 2
# 	n_neighbors = 3
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f3ce7490>
# Time: 0.006 s
# fitness=0.3333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = K Nearest Neighbors
# 	max_iter = 22
# 	alpha = 0.522
# 	max_depth = 3
# 	n_estimators = 2
# 	n_neighbors = 2
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f5077910>
# RUNNING EVAL FOR KNN
# Time: 0.005 s
# fitness=0.125
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 81
# 	alpha = 0.779
# 	max_depth = 7
# 	n_estimators = 7
# 	n_neighbors = 5
# 	length_scale = 0.3
#
# <see.base_classes.pipedata object at 0x7f06f6fae040>
# Time: 0.023 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = MLP Neural Network
# 	max_iter = 84
# 	alpha = 0.035
# 	max_depth = 4
# 	n_estimators = 5
# 	n_neighbors = 3
# 	length_scale = 0.4
#
# <see.base_classes.pipedata object at 0x7f06f4897490>
# Time: 0.315 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 97
# 	alpha = 0.991
# 	max_depth = 4
# 	n_estimators = 9
# 	n_neighbors = 5
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f8b26d00>
# Time: 0.02 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 65
# 	alpha = 0.964
# 	max_depth = 1
# 	n_estimators = 2
# 	n_neighbors = 4
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f8fb2f10>
# RUNNING EVAL FOR GNB
# Time: 0.002 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 65
# 	alpha = 0.407
# 	max_depth = 2
# 	n_estimators = 7
# 	n_neighbors = 7
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f43657f0>
# Time: 0.014 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Naive Bayes
# 	max_iter = 38
# 	alpha = 0.107
# 	max_depth = 5
# 	n_estimators = 6
# 	n_neighbors = 8
# 	length_scale = 0.8
#
# <see.base_classes.pipedata object at 0x7f06f46a94f0>
# RUNNING EVAL FOR GNB
# Time: 0.003 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 66
# 	alpha = 0.574
# 	max_depth = 5
# 	n_estimators = 7
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f52094f0>
# Time: 0.1 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 59
# 	alpha = 0.621
# 	max_depth = 4
# 	n_estimators = 2
# 	n_neighbors = 7
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f8911340>
# Time: 0.008 s
# fitness=0.16666666666666666
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 86
# 	alpha = 0.126
# 	max_depth = 1
# 	n_estimators = 2
# 	n_neighbors = 2
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f4427a90>
# Time: 0.057 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Random Forest
# 	max_iter = 66
# 	alpha = 0.574
# 	max_depth = 4
# 	n_estimators = 2
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f8ed7250>
# Time: 0.01 s
# fitness=0.08333333333333333
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 59
# 	alpha = 0.621
# 	max_depth = 5
# 	n_estimators = 7
# 	n_neighbors = 7
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f3d8ff40>
# Time: 0.075 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 86
# 	alpha = 0.126
# 	max_depth = 9
# 	n_estimators = 2
# 	n_neighbors = 2
# 	length_scale = 0.5
#
# <see.base_classes.pipedata object at 0x7f06f44d3730>
# Time: 0.064 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 5
# 	alpha = 0.933
# 	max_depth = 1
# 	n_estimators = 4
# 	n_neighbors = 6
# 	length_scale = 0.9
#
# <see.base_classes.pipedata object at 0x7f06f8911be0>
# Time: 0.054 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 10
# 	alpha = 0.773
# 	max_depth = 9
# 	n_estimators = 2
# 	n_neighbors = 4
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f6fae7f0>
# Time: 0.072 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 41
# 	alpha = 0.157
# 	max_depth = 2
# 	n_estimators = 4
# 	n_neighbors = 1
# 	length_scale = 0.2
#
# <see.base_classes.pipedata object at 0x7f06f46d6cd0>
# Time: 0.062 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 17
# 	alpha = 0.174
# 	max_depth = 9
# 	n_estimators = 7
# 	n_neighbors = 8
# 	length_scale = 0.6
#
# <see.base_classes.pipedata object at 0x7f06f46d6b80>
# Time: 0.062 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 39
# 	alpha = 0.739
# 	max_depth = 7
# 	n_estimators = 3
# 	n_neighbors = 5
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f46d6ac0>
# Time: 0.062 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 73
# 	alpha = 0.196
# 	max_depth = 6
# 	n_estimators = 1
# 	n_neighbors = 3
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f46d64f0>
# Time: 0.07 s
# fitness=0.041666666666666664
#
# <class 'see.Workflow.workflow'> parameters:
# 	algorithm = Gaussian Process
# 	max_iter = 54
# 	alpha = 0.78
# 	max_depth = 8
# 	n_estimators = 2
# 	n_neighbors = 8
# 	length_scale = 0.1
#
# <see.base_classes.pipedata object at 0x7f06f46d6ee0>
# Time: 0.065 s
# fitness=0.041666666666666664
#
# #BEST [0.041666666666666664,  ['Gaussian Process', 66, 0.574, 5, 7, 8, 0.1]]
# Mutating Population
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow
# using workflow mutate algorithm and looping over workflow

# %% [markdown]
# ## Plot Generation vs Fitness Score

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
from functools import reduce

# We loop because we expect multpile data files to have been
# generated (from running trials on the HPCC)
datasets_names = ["Moons", "Circles", "Linearly Separable"]
num_datasets = len(datasets_names)

# Init trials matrix
num_trials = len(glob.glob("{}_fitness_trial_*.csv".format(datasets_names[0])))

trial_matrix = np.empty((num_trials, num_datasets), dtype="object")

for i, ds in enumerate(datasets_names):
    files = sorted(glob.glob("{}_fitness_trial_*.csv".format(ds)))
    trial_matrix[:, i] = files

fig, axes = plt.subplots(nrows=num_datasets, ncols=num_trials, figsize=(50, 20))

trial_dataframes = []

# Use min_max to format axes
min_max = np.zeros((num_datasets, 2))
min_max[:, 0] = np.ones((1, num_datasets))

for i, trial in enumerate(trial_matrix):
    # Extract trial's data frames
    df_1 = pd.read_csv(trial[0], header=None)
    df_2 = pd.read_csv(trial[1], header=None)
    df_3 = pd.read_csv(trial[2], header=None)
    dfs = [df_1, df_2, df_3]

    # Combine data frames
    combined_dfs = reduce(
        lambda df_1, df_2: pd.merge(left=df_1, right=df_2, how="left", on=0), dfs
    )

    # Format columns and store trial data frame
    combined_dfs = combined_dfs.rename(
        columns={
            0: "Generation",
            "1_x": "Moons",
            "1_y": "Circles",
            1: "Linearly Separable",
        }
    )
    combined_dfs = combined_dfs.set_index("Generation")

    # TODO Iterate num_datasets
    current_min = combined_dfs["Moons"].min()
    current_max = combined_dfs["Moons"].max()
    if current_min < min_max[0][0]:
        min_max[0][0] = current_min
    if current_max > min_max[0][1]:
        min_max[0][1] = current_max

    current_min = combined_dfs["Circles"].min()
    current_max = combined_dfs["Circles"].max()
    if current_min < min_max[1][0]:
        min_max[1][0] = current_min
    if current_max > min_max[1][1]:
        min_max[1][1] = current_max

    current_min = combined_dfs["Linearly Separable"].min()
    current_max = combined_dfs["Linearly Separable"].max()
    if current_min < min_max[2][0]:
        min_max[2][0] = current_min
    if current_max > min_max[2][1]:
        min_max[2][1] = current_max

    trial_dataframes.append(combined_dfs)

    # Add trial titles
    axes[0][i].set_title("Trial {}".format(i + 1), {"fontsize": 25})


for i, trial in enumerate(trial_dataframes):
    # Plot trial
    a = trial.plot.line(fontsize=20, subplots=True, ax=axes[:, i], lw=8)

    # Format axis labels and set axes limits
    for j in range(num_datasets):
        # if i == 0:
        a[j].set_ylabel("Fitness Score", {"fontsize": 20})
        a[j].set_xlabel("Generation", {"fontsize": 20})

        a[j].set_ylim(min_max[j] - [0.01, -0.02])
        a[j].legend(loc=2, prop={"size": 20})

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-137-9e01eb2b339d> in <module>
#      30     # Extract trial's data frames
#      31     df_1 = pd.read_csv(trial[0], header=None)
# ---> 32     df_2 = pd.read_csv(trial[1], header=None)
#      33     df_3 = pd.read_csv(trial[2], header=None)
#      34     dfs = [df_1, df_2, df_3]
#
# ~/Documents/GitHub/see-segment/see-clasify/envs/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/Documents/GitHub/see-segment/see-clasify/envs/lib/python3.9/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/Documents/GitHub/see-segment/see-clasify/envs/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/Documents/GitHub/see-segment/see-clasify/envs/lib/python3.9/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/Documents/GitHub/see-segment/see-clasify/envs/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1896
#    1897         try:
# -> 1898             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#    1899         except Exception:
#    1900             self.handles.close()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file
